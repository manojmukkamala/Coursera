# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
#The framework for defining a neural network as a set of Sequential layers is called keras, so we import that too.

# %%
model = tf.keras.Sequential([keras.layers.Dense(units = 1, input_shape = [1])])
# Out:
# WARNING:tensorflow:From /Users/Manoj/anaconda3/lib/python3.7/site-packages/tensorflow/python/ops/resource_variable_ops.py:435: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %%
model.compile(optimizer = 'sgd', loss = 'mean_squared_error')
# Out:
# WARNING:tensorflow:From /Users/Manoj/anaconda3/lib/python3.7/site-packages/tensorflow/python/keras/utils/losses_utils.py:170: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.

# %%
xs = np.array([-1.0,  0.0, 1.0, 2.0, 3.0, 4.0], dtype=float)
ys = np.array([-3.0, -1.0, 1.0, 3.0, 5.0, 7.0], dtype=float)

# %%
model.fit(xs, ys, epochs=500)
# Out:
# WARNING:tensorflow:From /Users/Manoj/anaconda3/lib/python3.7/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 1/500
# 6/6 [==============================] - 0s 55ms/sample - loss: 1.5160
# Epoch 2/500
# 6/6 [==============================] - 0s 455us/sample - loss: 1.3295
# Epoch 3/500
# 6/6 [==============================] - 0s 757us/sample - loss: 1.1799
# Epoch 4/500
# 6/6 [==============================] - 0s 394us/sample - loss: 1.0595
# Epoch 5/500
# 6/6 [==============================] - 0s 693us/sample - loss: 0.9621
# Epoch 6/500
# 6/6 [==============================] - 0s 731us/sample - loss: 0.8828
# Epoch 7/500
# 6/6 [==============================] - 0s 384us/sample - loss: 0.8178
# Epoch 8/500
# 6/6 [==============================] - 0s 302us/sample - loss: 0.7642
# Epoch 9/500
# ...

# %%
print(model.predict([10]))
# Out:
# [[18.986145]]

# %%
model2 = tf.keras.Sequential([keras.layers.Dense(units = 1, input_shape = [1])], [keras.layers.Dense(units = 1)])

# %%
model2.compile(optimizer='sgd', loss='mean_squared_error')

# %%
xs = np.array([-1.0,  0.0, 1.0, 2.0, 3.0, 4.0], dtype=float)
ys = np.array([-3.0, -1.0, 1.0, 3.0, 5.0, 7.0], dtype=float)

# %%
model2.fit(xs, ys, epochs = 500)
# Out:
# Epoch 1/500
# 6/6 [==============================] - 0s 24ms/sample - loss: 25.3661
# Epoch 2/500
# 6/6 [==============================] - 0s 248us/sample - loss: 20.2488
# Epoch 3/500
# 6/6 [==============================] - 0s 327us/sample - loss: 16.2168
# Epoch 4/500
# 6/6 [==============================] - 0s 473us/sample - loss: 13.0388
# Epoch 5/500
# 6/6 [==============================] - 0s 806us/sample - loss: 10.5327
# Epoch 6/500
# 6/6 [==============================] - 0s 644us/sample - loss: 8.5554
# Epoch 7/500
# 6/6 [==============================] - 0s 399us/sample - loss: 6.9942
# Epoch 8/500
# 6/6 [==============================] - 0s 286us/sample - loss: 5.7605
# Epoch 9/500
# 6/6 [==============================] - 0s 321us/sample - loss: 4.7846
# Epoch 10/500
# 6/6 [==============================] - 0s 624us/sample - loss: 4.0117
# Epoch 11/500
# 6/6 [==============================] - 0s 270us/sample - loss: 3.3985
# Epoch 12/500
# ...

# %%
print(model2.predict([10]))
# Out:
# [[18.979752]]

# %%
model3 = tf.keras.Sequential([keras.layers.Dense(units = 1, input_shape = [1])], [keras.layers.Dense(units = 3)])

# %%
model3.compile(optimizer = 'sgd', loss = 'mean_squared_error')

# %%
model3.fit(xs, ys, epochs = 500)
# Out:
# Epoch 1/500
# 6/6 [==============================] - 0s 27ms/sample - loss: 0.6839
# Epoch 2/500
# 6/6 [==============================] - 0s 260us/sample - loss: 0.6557
# Epoch 3/500
# 6/6 [==============================] - 0s 387us/sample - loss: 0.6311
# Epoch 4/500
# 6/6 [==============================] - 0s 260us/sample - loss: 0.6094
# Epoch 5/500
# 6/6 [==============================] - 0s 719us/sample - loss: 0.5900
# Epoch 6/500
# 6/6 [==============================] - 0s 597us/sample - loss: 0.5724
# Epoch 7/500
# 6/6 [==============================] - 0s 599us/sample - loss: 0.5564
# Epoch 8/500
# 6/6 [==============================] - 0s 408us/sample - loss: 0.5416
# Epoch 9/500
# 6/6 [==============================] - 0s 875us/sample - loss: 0.5279
# Epoch 10/500
# 6/6 [==============================] - 0s 611us/sample - loss: 0.5149
# Epoch 11/500
# 6/6 [==============================] - 0s 266us/sample - loss: 0.5027
# Epoch 12/500
# ...

# %%
model3.predict([10])
# Out:
# array([[18.98715]], dtype=float32)
